# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
# Out:
# Init Plugin
# Init Graph Optimizer
# Init Kernel

# %%
type(bad_path[1])
# Out:
# str

# %%
from PIL import Image
import cv2
import matplotlib

good_path = '/Users/tori/Desktop/workspace/moss/MOSS/66.png'
bad_path = ['/Users/tori/Desktop/workspace/moss/MOSS/486_b.png', '/Users/tori/Desktop/workspace/moss/MOSS/325_b.png']

good_img = cv2.imread(good_path)
bad_img = cv2.imread(bad_path[1])

plt.subplot(1, 2, 1)
plt.title('Bad sample')
plt.imshow(bad_img)

plt.subplot(1, 2, 2)
plt.title('Good sample')
plt.imshow(good_img)

# %%
# 파일명을 인자로 받아 해당 이미지 파일과 히스토그램을 출력해 주는 함수
def draw_color_histogram_from_image(image_path):
    # 이미지 열기
    img = Image.open(image_path)
    cv_image = cv2.imread(image_path)

    # Image와 Histogram 그려보기
    f=plt.figure(figsize=(10,3))
    im1 = f.add_subplot(1,2,1)
    im1.imshow(img)
    im1.set_title("Image")

    im2 = f.add_subplot(1,2,2)
    color = ('b','g','r')
    for i,col in enumerate(color):
        # image에서 i번째 채널의 히스토그램을 뽑아서(0:blue, 1:green, 2:red)
        histr = cv2.calcHist([cv_image],[i],None,[256],[0,256])   
        im2.plot(histr,color = col)   # 그래프를 그릴 때 채널 색상과 맞춰서 그립니다.
    im2.set_title("Histogram")

# %%
draw_color_histogram_from_image(good_path)

# %%
draw_color_histogram_from_image(bad_path[1])
